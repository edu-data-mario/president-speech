# %%
speech = """존경하고 사랑하는 국민 여러분!
감사합니다. 국민 여러분의 위대한 선택에 머리 숙여 깊이 감사드립니다.

저는 오늘 대한민국 제19대 대통령으로서 새로운 대한민국을 향해 첫걸음을내딛습니다. 지금 제 두 어깨는 국민 여러분으로부터 부여받은 막중한 소명감으로 무겁습니다. 지금 제 가슴은 한 번도 경험하지 못한 나라를 만들겠다는 열정으로 뜨겁습니다. 그리고 지금 제 머리는 통합과 공존의 새로운 세상을 열어 갈청사진으로 가득 차 있습니다.

우리가 만들어 가려는 새로운 대한민국은 숱한 좌절과 패배에도 불구하고 우리 선대들이 일관되게 추구했던 나라입니다. 또한 많은 희생과 헌신을 감내하며 우리 젊은이들이 그토록 이루고 싶어 했던 나라입니다. 그런 대한민국을 만들기위해 저는 역사와 국민 앞에 두렵지만 겸허히 대한민국 제19대 대통령으로서 책임과 소명을 다할 것을 천명합니다.

함께 선거를 치른 후보들께 감사의 말씀과 함께 심심한 위로를 전합니다. 이번 선거에서는 승자도 패자도 없습니다. 우리는 새로운 대한민국을 함께 이끌어 가야 할 동반자입니다. 이제 치열했던 경쟁의 순간을 뒤로하고 함께 손을 맞잡고 미래로 전진해야 합니다.

존경하는 국민 여러분!
지난 몇 달간 우리는 유례없는 정치적 격변기를 보냈습니다. 정치는 혼란했지만 국민은 위대했습니다. 현직 대통령의 탄핵과 구속 앞에서도 국민께서 대한민국의 앞길을 열어 주셨습니다. 우리 국민은 좌절하지 않고 오히려 전화위복의 계기로 삼아 마침내 오늘 새로운 세상을 열었습니다. 대한민국의 위대함은 국민의 위대함입니다. 그리고 이번 대통령 선거에서 우리 국민은 또 하나의 역사를 만들어 주셨습니다. 전국 각지에서 고른 지지로 새로운 대한민국을 선택해 주셨습니다. 오늘부터 저는 국민 모두의 대통령이 되겠습니다. 저를 지지하지 않았던 분도 진심으로 우리의 국민으로 섬기겠습니다. 저는 감히 약속드립니다. 2017년 5월 10일은 진정한 국민통합이 시작된 날로 역사에 기록될 것입니다.

존경하고 사랑하는 국민 여러분!
힘들었던 지난 세월 국민은 이게 나라냐고 물었습니다. 대통령 문재인은 바로그 질문에서 시작하겠습니다.
오늘부터 나라를 나라답게 만드는 대통령이 되겠습니다. 구시대의 잘못된 관행과 과감히 결별하겠습니다. 대통령부터 새로워지겠습니다.
우선 권위적 대통령 문화를 청산하겠습니다. 준비를 마치는 대로 지금의 청와대에서 나와서 광화문 대통령 시대를 열겠습니다. 참모들과 머리와 어깨를 맞대고 토론하겠습니다. 국민과 수시로 소통하는 대통령이 되겠습니다. 주요 사안은대통령이 직접 언론에 브리핑하겠습니다. 퇴근길에는 시장에 들러 마주치는 시민 여러분과 격의 없는 대화를 나누겠습니다. 때로는 광화문광장에서 대토론회를 열겠습니다. 대통령의 제왕적 권력을 최대한 나누겠습니다.
권력기관은 정치로부터 완전히 독립시키겠습니다. 그 어떤 기관도 무소불위의권력을 행사할 수 없도록 견제 장치를 만들겠습니다. 낮은 자세로 일하겠습니다.

국민과 눈높이를 맞추는 대통령이 되겠습니다.
안보위기도 서둘러 해결하겠습니다. 한반도 평화를 위해 동분서주하겠습니다.
필요하면 곧바로 워싱턴으로 날아가겠습니다. 베이징(北京)과 도쿄(東京)에도 가고, 여건이 조성되면 평양에도 가겠습니다. 한반도 평화 정착을 위해서라면 제가할 수 있는 모든 일을 다하겠습니다. 한미동맹은 더욱 강화하겠습니다. 한편으로사드 문제 해결을 위해 미국 및 중국과 진지하게 협상하겠습니다. 튼튼한 안보는막강한 국방력에서 비롯됩니다. 자주국방을 강화하기 위해 노력하겠습니다. 북핵문제를 해결할 토대도 마련하겠습니다. 동북아 평화 구조를 정착시킴으로써한반도 긴장완화의 전기를 마련하겠습니다.
분열과 갈등의 정치도 바꾸겠습니다. 보수와 진보의 갈등은 끝나야 합니다. 대통령이 나서서 직접 대화하겠습니다. 야당은 국정운영의 동반자입니다. 대화를정례화하고 수시로 만나겠습니다.
전국의 인재를 고르게 등용하겠습니다. 능력과 적재적소(適材適所)를 인사의 대원칙으로 삼겠습니다. 저에 대한 지지 여부와 상관없이 유능한 인재를 삼고초려(三顧草廬)해서 일을 맡기겠습니다.
나라 안팎으로 경제가 어렵습니다. 민생도 어렵습니다. 선거 과정에서 약속했듯이 무엇보다 먼저 일자리를 챙기겠습니다. 동시에 재벌 개혁에도 앞장서겠습니다.
문재인정부 시대에는 정경유착이라는 말이 완전히 사라질 것입니다. 지역과 계층과 세대 간 갈등을 해소하고, 비정규직 문제도 해결의 길을 모색하겠습니다. 차별 없는 세상을 만들겠습니다.

거듭 말씀드립니다.
문재인과 더불어민주당 정부에서 기회는 평등할 것입니다.
과정은 공정할 것입니다.
결과는 정의로울 것입니다.

존경하는 국민 여러분!
이번 대통령 선거는 전임 대통령의 탄핵으로 치렀습니다. ‘불행한 대통령’의역사가 계속되고 있습니다. 문재인정부를 시작으로 이런 불행한 역사는 종식되어야 합니다. 저는 대한민국 대통령의 새로운 모범이 되겠습니다. 국민과 역사가평가하는 성공한 대통령이 되기 위해 최선을 다하겠습니다. 그것으로 지지와 성원에 보답하겠습니다.
깨끗한 대통령이 되겠습니다. 빈손으로 취임하고 빈손으로 퇴임하는 대통령이되겠습니다. 훗날 고향으로 돌아가 평범한 시민이 되어 이웃과 정을 나누며 사는대통령이 되겠습니다. 국민 여러분의 자랑으로 남겠습니다.
약속을 지키는 솔직한 대통령이 되겠습니다. 선거 과정에서 제가 했던 약속들을 꼼꼼하게 챙겨서 지키겠습니다. 대통령부터 신뢰받는 정치를 솔선수범해야 진정한 정치 발전이 가능할 것입니다. 불가능한 일을 하겠다고 큰소리치지 않겠습니다. 잘못한 일은 잘못했다고 말씀드리겠습니다. 거짓으로 불리한 여론을 덮지 않겠습니다.
공정한 대통령이 되겠습니다. 특권과 반칙이 없는 세상을 만들겠습니다. 상식대로 해야 이득을 보는 세상을 만들겠습니다.
이웃의 아픔을 외면하지 않겠습니다. 소외된 국민이 없도록 노심초사하는 마음으로 항상 살피겠습니다. 국민의 서러운 눈물을 닦아 드리는 대통령이 되겠습니다.
소통하는 대통령이 되겠습니다. 낮은 사람, 겸손한 권력이 되어 가장 강력한 나라를 만들겠습니다. 군림하고 통치하는 대통령이 아니라 대화하고 소통하는 대통령이 되겠습니다.
‘광화문 시대 대통령’이 되어 국민과 가까운 곳에 있겠습니다. 따뜻한 대통령,친구 같은 대통령으로 남겠습니다.

사랑하고 존경하는 국민 여러분!
2017년 5월 10일 오늘 대한민국이 다시 시작합니다. 나라를 나라답게 만드는역사가 시작됩니다. 이 길에 함께해 주십시오. 저의 신명을 바쳐 일하겠습니다.
감사합니다."""

# %%
speech = """존경하고 사랑하는 국민 여러분!
감사합니다. 국민 여러분의 위대한 선택에 머리 숙여 깊이 감사드립니다."""

# %%
def print_result(r: list):
    print(f'{len(r)}:{len(set(r))}')

# %%
from konlpy.tag import Okt
okt = Okt()

okt_r = okt.nouns(speech)
print_result(okt_r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 okt = Okt()
#       4 okt_r = okt.nouns(speech)
# ----> 5 print_result(okt_r)
#
# NameError: name 'print_result' is not defined

# %%
okt_r_p = okt.phrases(speech)
print_result(okt_r)
# Out:
# 498:284

# %%
okt_r_c = Counter(okt_r)

# %%
okt_r_c
# Out:
# Counter({'존경': 5,
#          '사랑': 3,
#          '국민': 24,
#          '여러분': 9,
#          '선택': 2,
#          '머리': 3,
#          '깊이': 1,
#          '감사': 2,
#          '저': 8,
#          '오늘': 5,
#          '대한민국': 11,
#          '제': 7,
#          '대통령': 33,
#          '향': 1,
#          '첫걸음': 1,
#          '지금': 4,
#          '두': 1,
#          '어깨': 2,
#          '부여': 1,
#          '막중': 1,
#          '명감': 1,
#          '가슴': 1,
#          '번': 1,
#          '경험': 1,
#          '못': 1,
#          '나라': 7,
#          '열정': 1,
#          '통합': 2,
#          '공존': 1,
#          '세상': 5,
#          '청사진': 1,
#          '가득': 1,
#          '차': 1,
#          '우리': 8,
#          '숱': 1,
#          '좌절': 2,
#          '패배': 1,
#          '불구': 1,
#          '선대': 1,
#          '일관': 1,
#          '추구': 1,
#          '또한': 1,
#          '희생': 1,
#          '헌신': 1,
#          '젊은이': 1,
#          '만들기': 1,
#          '위해': 5,
#          '역사': 6,
#          '앞': 2,
#          '겸허': 1,
#          '책임': 1,
#          '소명': 1,
#          '것': 7,
#          '천명': 1,
#          '선거': 6,
#          '후보': 1,
#          '말씀': 1,
#          '위로': 1,
#          '전': 1,
#          '이번': 3,
#          '승자': 1,
#          '패자': 1,
#          '가야': 1,
#          '동반': 2,
#          '이제': 1,
#          '경쟁': 1,
#          '순간': 1,
#          '뒤로': 1,
#          '손': 1,
#          '잡고': 1,
#          '미래': 1,
#          '전진': 1,
#          '지난': 2,
#          '몇': 1,
#          '달': 1,
#          '유례': 1,
#          '정치': 6,
#          '격변': 1,
#          '혼란': 1,
#          '현직': 1,
#          '탄핵': 2,
#          '구속': 1,
#          '앞길': 1,
#          '오히려': 1,
#          '전화위복': 1,
#          '계기': 1,
#          '마침내': 1,
#          '또': 1,
#          '하나': 1,
#          '전국': 2,
#          '각지': 1,
#          '지지': 4,
#          '모두': 1,
#          '분도': 1,
#          '진심': 1,
#          '감히': 2,
#          '약속': 4,
#          '시작': 5,
#          '날로': 1,
#          '기록': 1,
#          '세월': 1,
#          '이': 3,
#          '문재인': 4,
#          '바': 1,
#          '로그': 1,
#          '질문': 1,
#          '구시대': 1,
#          '관행': 1,
#          '과': 2,
#          '결별': 1,
#          '우선': 1,
#          '권위': 1,
#          '문화': 1,
#          '청산': 1,
#          '준비': 1,
#          '대로': 1,
#          '청와대': 1,
#          '광화문': 3,
#          '시대': 3,
#          '참모': 1,
#          '토론': 1,
#          '소통': 3,
#          '주요': 1,
#          '사안': 1,
#          '직접': 2,
#          '언론': 1,
#          '브리핑': 1,
#          '퇴근길': 1,
#          '시장': 1,
#          '시민': 2,
#          '격의': 1,
#          '대화': 4,
#          '때로는': 1,
#          '광장': 1,
#          '토론회': 1,
#          '제왕': 1,
#          '권력': 4,
#          '최대한': 1,
#          '기관': 2,
#          '로부터': 1,
#          '독립': 1,
#          '그': 1,
#          '무소': 1,
#          '불위': 1,
#          '행사': 1,
#          '수': 2,
#          '견제': 1,
#          '장치': 1,
#          '자세': 1,
#          '일': 6,
#          '눈높이': 1,
#          '안보': 2,
#          '위기': 1,
#          '해결': 4,
#          '한반도': 3,
#          '평화': 3,
#          '동분서주': 1,
#          '곧바로': 1,
#          '워싱턴': 1,
#          '베이징': 1,
#          '도쿄': 1,
#          '여건': 1,
#          '조성': 1,
#          '평양': 1,
#          '정착': 2,
#          '위': 1,
#          '모든': 1,
#          '한미': 1,
#          '동맹': 1,
#          '더욱': 1,
#          '한편': 1,
#          '사드': 1,
#          '문제': 2,
#          '미국': 1,
#          '및': 1,
#          '중국': 1,
#          '협상': 1,
#          '막강': 1,
#          '국방력': 1,
#          '비롯': 1,
#          '자주': 1,
#          '국방': 1,
#          '노력': 1,
#          '북핵문제': 1,
#          '토대': 1,
#          '마련': 2,
#          '동북아': 1,
#          '구조': 1,
#          '시킴': 1,
#          '긴장': 1,
#          '완화': 1,
#          '전기': 1,
#          '분열': 1,
#          '갈등': 3,
#          '보수': 1,
#          '진보': 1,
#          '야당': 1,
#          '국정': 1,
#          '운영': 1,
#          '정례': 1,
#          '인재': 2,
#          '등용': 1,
#          '능력': 1,
#          '적재적소': 1,
#          '를': 1,
#          '인사': 1,
#          '원칙': 1,
#          '대한': 1,
#          '여부': 1,
#          '삼고초려': 1,
#          '안팎': 1,
#          '경제': 1,
#          '민생': 1,
#          '과정': 3,
#          '무엇': 1,
#          '먼저': 1,
#          '일자리': 1,
#          '동시': 1,
#          '재벌': 1,
#          '개혁': 1,
#          '정부': 3,
#          '정경': 1,
#          '유착': 1,
#          '말': 1,
#          '지역': 1,
#          '계층': 1,
#          '세대': 1,
#          '간': 1,
#          '해소': 1,
#          '비정규직': 1,
#          '길': 2,
#          '모색': 1,
#          '차별': 1,
#          '거듭': 1,
#          '민주당': 1,
#          '기회': 1,
#          '결과': 1,
#          '정의': 1,
#          '울': 1,
#          '전임': 1,
#          '의역': 1,
#          '사가': 1,
#          '계속': 1,
#          '종식': 1,
#          '모범': 1,
#          '가평': 1,
#          '최선': 1,
#          '그것': 1,
#          '성원': 1,
#          '보답': 1,
#          '빈손': 2,
#          '취임': 1,
#          '퇴': 1,
#          '훗날': 1,
#          '고향': 1,
#          '이웃': 2,
#          '정': 1,
#          '자랑': 1,
#          '신뢰': 1,
#          '솔선수범': 1,
#          '발전': 1,
#          '잘못': 1,
#          '거짓': 1,
#          '여론': 1,
#          '특권': 1,
#          '반칙': 1,
#          '상식': 1,
#          '이득': 1,
#          '아픔': 1,
#          '외면': 1,
#          '소외': 1,
#          '노심초사': 1,
#          '마음': 1,
#          '항상': 1,
#          '눈물': 1,
#          '사람': 1,
#          '가장': 1,
#          '군림': 1,
#          '통치': 1,
#          '곳': 1,
#          '친구': 1,
#          '다시': 1,
#          '시오': 1,
#          '신명': 1})

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()
hannanum_r = hannanum.nouns(speech)
print_result(hannanum_r)
# Out:
# 463:283

# %%
hannanum_r_c = Counter(hannanum_r)

# %%
type(hannanum_r_c)
# Out:
# collections.Counter

# %%
hannanum_r_c.most_common(3)
# Out:
# [('대통령', 24), ('국민', 23), ('저', 12)]

# %%
hannanum_r_c
# Out:
# Counter({'존경': 5,
#          '사랑': 3,
#          '국민': 23,
#          '여러분': 9,
#          '감사': 3,
#          '위대한': 1,
#          '선택': 2,
#          '머리': 3,
#          '저': 12,
#          '오늘': 5,
#          '대한민국': 11,
#          '제19대': 2,
#          '대통령': 24,
#          '첫걸음을내딛습니': 1,
#          '두': 1,
#          '어깨': 2,
#          '부': 1,
#          '막중': 1,
#          '소명감': 1,
#          '가슴': 1,
#          '번': 1,
#          '경험': 1,
#          '나라': 7,
#          '열정': 1,
#          '통합': 1,
#          '공존': 1,
#          '세상': 5,
#          '갈청사진': 1,
#          '우리': 8,
#          '좌절': 2,
#          '패배': 1,
#          '불구': 1,
#          '선대들': 1,
#          '일관': 1,
#          '추구': 1,
#          '희생': 1,
#          '헌신': 1,
#          '감내': 1,
#          '젊은이들': 1,
#          '만들기위해': 1,
#          '역사': 4,
#          '앞': 2,
#          '겸허': 1,
#          '책': 1,
#          '소명': 1,
#          '것': 8,
#          '천명': 1,
#          '선거': 5,
#          '후보들': 1,
#          '말씀': 1,
#          '심심': 1,
#          '위로': 1,
#          '이번': 3,
#          '승자': 1,
#          '패자': 1,
#          '동반자': 2,
#          '치열': 1,
#          '경쟁': 1,
#          '순간': 1,
#          '뒤': 1,
#          '손': 1,
#          '미래': 1,
#          '전진': 1,
#          '몇': 1,
#          '간': 1,
#          '정치적': 1,
#          '격변기': 1,
#          '정치': 5,
#          '혼란': 1,
#          '위대': 1,
#          '현직': 1,
#          '대통령의': 4,
#          '탄핵': 2,
#          '구속': 1,
#          '앞길': 1,
#          '전화위복': 1,
#          '계기': 1,
#          '위대함': 2,
#          '하나': 1,
#          '전국': 2,
#          '각지': 1,
#          '지지': 1,
#          '모두': 1,
#          '분': 1,
#          '진심': 1,
#          '약속드': 1,
#          '2017년': 2,
#          '5월': 2,
#          '10일': 2,
#          '진정한': 2,
#          '국민통합': 1,
#          '시작': 5,
#          '날': 1,
#          '기록': 1,
#          '세월': 1,
#          '이': 1,
#          '문재인': 2,
#          '바로그': 1,
#          '질문': 1,
#          '나라답': 2,
#          '구시대': 1,
#          '잘못된': 1,
#          '관행': 1,
#          '결별': 1,
#          '권위적': 1,
#          '문화': 1,
#          '청산': 1,
#          '준비': 1,
#          '대': 1,
#          '지금': 1,
#          '청와대': 1,
#          '광화문': 1,
#          '시대': 3,
#          '참모': 1,
#          '토론': 1,
#          '수시': 1,
#          '소통': 3,
#          '주요': 1,
#          '사안은대통령': 1,
#          '언론': 1,
#          '브리핑': 1,
#          '퇴근길': 1,
#          '시장': 1,
#          '시민': 2,
#          '격': 1,
#          '대화': 3,
#          '때': 1,
#          '광화문광장': 1,
#          '대토론회': 1,
#          '제왕적': 1,
#          '권력': 2,
#          '권력기관': 1,
#          '독립': 1,
#          '기관': 1,
#          '무소불위의권력': 1,
#          '행사': 1,
#          '수': 2,
#          '견제': 1,
#          '장치': 1,
#          '낮': 2,
#          '자세': 1,
#          '일': 6,
#          '눈높이': 1,
#          '안보위': 1,
#          '해결': 4,
#          '한반': 2,
#          '평화': 3,
#          '동분서주': 1,
#          '필요': 1,
#          '워싱턴': 1,
#          '베이징(北京)': 1,
#          '도쿄(東京)': 1,
#          '여건': 1,
#          '조성': 1,
#          '평양': 1,
#          '정착': 1,
#          '제가': 1,
#          '한미동맹': 1,
#          '강화': 2,
#          '한편으로사드': 1,
#          '문제': 2,
#          '미국': 1,
#          '중국': 1,
#          '진지': 1,
#          '협상': 1,
#          '튼튼': 1,
#          '안보는막강한': 1,
#          '국방력': 1,
#          '비롯': 1,
#          '자주국방': 1,
#          '노력': 1,
#          '북핵문제': 1,
#          '토대': 1,
#          '마련': 2,
#          '동북': 1,
#          '구조': 1,
#          '정착시킴으로써한반': 1,
#          '긴장완화': 1,
#          '전기': 1,
#          '분열': 1,
#          '등': 3,
#          '보수': 1,
#          '진보': 1,
#          '야당': 1,
#          '국정운영': 1,
#          '대화를정례화하': 1,
#          '인재': 2,
#          '등용': 1,
#          '능력': 1,
#          '적재적소(適材適所)': 1,
#          '인사': 1,
#          '대원칙': 1,
#          '지': 1,
#          '여부': 1,
#          '유능': 1,
#          '삼고초려(三顧草廬)해서': 1,
#          '안팎': 1,
#          '경제': 1,
#          '민생': 1,
#          '과정': 3,
#          '약속': 2,
#          '무엇': 1,
#          '일자리': 1,
#          '재벌': 1,
#          '개혁': 1,
#          '문재인정부': 2,
#          '정경유착': 1,
#          '말': 1,
#          '지역': 1,
#          '계층': 1,
#          '세대': 1,
#          '해소': 1,
#          '정규직': 1,
#          '길': 2,
#          '모색': 1,
#          '차별': 1,
#          '더불어민주당': 1,
#          '정부': 1,
#          '기회': 1,
#          '평등': 1,
#          '공정': 1,
#          '결과': 1,
#          '정의': 1,
#          '전': 1,
#          '‘불행한': 1,
#          '대통령’의역사': 1,
#          '계속': 1,
#          '불행': 1,
#          '종식': 1,
#          '모범': 1,
#          '역사가평가': 1,
#          '성공': 1,
#          '최선': 1,
#          '그것': 1,
#          '성원': 1,
#          '보답': 1,
#          '깨끗': 1,
#          '빈손': 2,
#          '취': 1,
#          '퇴임': 1,
#          '대통령이': 1,
#          '훗날': 1,
#          '고향': 1,
#          '평범': 1,
#          '이웃과': 1,
#          '정': 1,
#          '사는대통령': 1,
#          '자랑': 1,
#          '솔직한': 1,
#          '약속들': 1,
#          '신뢰': 1,
#          '솔선수범': 1,
#          '발전': 1,
#          '가능': 1,
#          '불가능': 1,
#          '잘못한': 1,
#          '잘못': 1,
#          '거짓': 1,
#          '불리': 1,
#          '여론': 1,
#          '공정한': 1,
#          '특권': 1,
#          '반칙': 1,
#          '상식': 1,
#          '이득': 1,
#          '이웃': 1,
#          '외면': 1,
#          '소외': 1,
#          '노심초사': 1,
#          '마음': 1,
#          '눈물': 1,
#          '사람': 1,
#          '겸손': 1,
#          '강력': 1,
#          '군림': 1,
#          '통치하': 1,
#          '‘광화문': 1,
#          '대통령’': 1,
#          '곳': 1,
#          '따뜻한': 1,
#          '친구': 1,
#          '만드는역사': 1,
#          '신명': 1})

# %%
from konlpy.tag import Kkma
kkma = Kkma()
kkma_r = kkma.nouns(speech)
print_result(kkma_r)
# Out:
# 297:294

# %%
from collections import Counter
ct = Counter(kkma_r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from collections import Counter
# ----> 2 ct = Counter(kkma_r)
#
# NameError: name 'kkma_r' is not defined

# %%
set(kkma_r)
# Out:
# {'10',
#  '10일',
#  '19',
#  '2017',
#  '2017년',
#  '5',
#  '5월',
#  '가능',
#  '가슴',
#  '각지',
#  '간',
#  '갈등',
#  '갈청',
#  '갈청사진',
#  '감내',
#  '감사',
#  '강화',
#  '개혁',
#  '거짓',
#  '격변기',
#  '격의',
#  '견제',
#  '결과',
#  '결별',
#  '겸손',
#  '경쟁',
#  '경제',
#  '경험',
#  '계기',
#  '계속',
#  '계층',
#  '고향',
#  '곳',
#  '공정',
#  '공존',
#  '과',
#  '과정',
#  '관행',
#  '광장',
#  '광화문',
#  '광화문광장',
#  '구속',
#  '구시대',
#  '구조',
#  '국민',
#  '국민통합',
#  '국방',
#  '국방력',
#  '국정',
#  '국정운영',
#  '군림',
#  '권력',
#  '권력기관',
#  '권위',
#  '그것',
#  '기관',
#  '기록',
#  '기회',
#  '긴장',
#  '긴장완화',
#  '길',
#  '나라',
#  '날',
#  '년',
#  '노력',
#  '노심초사',
#  '눈높이',
#  '눈물',
#  '능력',
#  '달',
#  '달간',
#  '대',
#  '대로',
#  '대원칙',
#  '대통령',
#  '대한',
#  '대한민국',
#  '대화',
#  '도쿄',
#  '독립',
#  '동맹',
#  '동반자',
#  '동북아',
#  '동분서주',
#  '동시',
#  '등용',
#  '라면',
#  '마련',
#  '마음',
#  '막강',
#  '말',
#  '말씀',
#  '머리',
#  '모두',
#  '모범',
#  '모색',
#  '무소불위',
#  '무엇',
#  '문',
#  '문재',
#  '문재인',
#  '문재인정부',
#  '문제',
#  '문제도',
#  '문화',
#  '미',
#  '미국',
#  '미동맹',
#  '미래',
#  '민국',
#  '민생',
#  '민주당',
#  '반칙',
#  '발전',
#  '번',
#  '베이징',
#  '보답',
#  '보수',
#  '북',
#  '북핵문제',
#  '분',
#  '분열',
#  '불가능',
#  '불리',
#  '불행',
#  '브리핑',
#  '빈손',
#  '사드',
#  '사람',
#  '사랑',
#  '사안',
#  '사진',
#  '상식',
#  '새',
#  '선거',
#  '선대',
#  '선택',
#  '성공',
#  '성원',
#  '세대',
#  '세상',
#  '세월',
#  '소',
#  '소명',
#  '소명감',
#  '소외',
#  '소통',
#  '손',
#  '솔선수범',
#  '수',
#  '순간',
#  '숱',
#  '승자',
#  '시대',
#  '시민',
#  '시작',
#  '시장',
#  '신뢰',
#  '신명',
#  '아픔',
#  '안보',
#  '안보위기',
#  '안팎',
#  '앞',
#  '앞길',
#  '야당',
#  '약속',
#  '어깨',
#  '언론',
#  '여건',
#  '여러분',
#  '여론',
#  '여부',
#  '역사',
#  '역사가',
#  '역사가평가',
#  '열정',
#  '오늘',
#  '완화',
#  '외면',
#  '우리',
#  '운영',
#  '워',
#  '워싱턴',
#  '월',
#  '위기',
#  '위대',
#  '위로',
#  '위복',
#  '유능',
#  '유착',
#  '이',
#  '이것',
#  '이득',
#  '이번',
#  '이웃',
#  '인',
#  '인사',
#  '인재',
#  '일',
#  '일관',
#  '일자리',
#  '자랑',
#  '자세',
#  '자주',
#  '자주국방',
#  '잘못',
#  '장치',
#  '재벌',
#  '재인',
#  '저',
#  '적재',
#  '전국',
#  '전기',
#  '전임',
#  '전진',
#  '전화',
#  '전화위복',
#  '젊은이',
#  '정',
#  '정경',
#  '정경유착',
#  '정규직',
#  '정례',
#  '정부',
#  '정의',
#  '정착',
#  '정치',
#  '정치적',
#  '제',
#  '제19대',
#  '제가',
#  '제도',
#  '제왕',
#  '조성',
#  '존경',
#  '종식',
#  '좌절',
#  '주요',
#  '준비',
#  '중국',
#  '지금',
#  '지역',
#  '지지',
#  '진보',
#  '진심',
#  '진정',
#  '질문',
#  '차별',
#  '참모',
#  '책임',
#  '천명',
#  '첫걸음',
#  '청산',
#  '청와대',
#  '초려',
#  '최대한',
#  '최선',
#  '추구',
#  '취임',
#  '치열',
#  '친구',
#  '탄핵',
#  '토대',
#  '토론',
#  '토론회',
#  '통치',
#  '통합',
#  '퇴근길',
#  '퇴임',
#  '특권',
#  '튼튼',
#  '패배',
#  '패자',
#  '평가',
#  '평등',
#  '평범한',
#  '평양',
#  '평화',
#  '필요',
#  '하나',
#  '한반도',
#  '한편',
#  '해결',
#  '해소',
#  '핵',
#  '행사',
#  '헌신',
#  '현직',
#  '협상',
#  '혼란',
#  '후보',
#  '훗날',
#  '희생'}

# %%
set(hannanum_r)
# Out:
# {'10일',
#  '2017년',
#  '5월',
#  '‘광화문',
#  '‘불행한',
#  '가능',
#  '가슴',
#  '각지',
#  '간',
#  '갈청사진',
#  '감내',
#  '감사',
#  '강력',
#  '강화',
#  '개혁',
#  '거짓',
#  '것',
#  '격',
#  '격변기',
#  '견제',
#  '결과',
#  '결별',
#  '겸손',
#  '겸허',
#  '경쟁',
#  '경제',
#  '경험',
#  '계기',
#  '계속',
#  '계층',
#  '고향',
#  '곳',
#  '공정',
#  '공정한',
#  '공존',
#  '과정',
#  '관행',
#  '광화문',
#  '광화문광장',
#  '구속',
#  '구시대',
#  '구조',
#  '국민',
#  '국민통합',
#  '국방력',
#  '국정운영',
#  '군림',
#  '권력',
#  '권력기관',
#  '권위적',
#  '그것',
#  '기관',
#  '기록',
#  '기회',
#  '긴장완화',
#  '길',
#  '깨끗',
#  '나라',
#  '나라답',
#  '날',
#  '낮',
#  '노력',
#  '노심초사',
#  '눈높이',
#  '눈물',
#  '능력',
#  '대',
#  '대원칙',
#  '대토론회',
#  '대통령',
#  '대통령’',
#  '대통령’의역사',
#  '대통령의',
#  '대통령이',
#  '대한민국',
#  '대화',
#  '대화를정례화하',
#  '더불어민주당',
#  '도쿄(東京)',
#  '독립',
#  '동반자',
#  '동북',
#  '동분서주',
#  '두',
#  '뒤',
#  '등',
#  '등용',
#  '따뜻한',
#  '때',
#  '마련',
#  '마음',
#  '막중',
#  '만드는역사',
#  '만들기위해',
#  '말',
#  '말씀',
#  '머리',
#  '몇',
#  '모두',
#  '모범',
#  '모색',
#  '무소불위의권력',
#  '무엇',
#  '문재인',
#  '문재인정부',
#  '문제',
#  '문화',
#  '미국',
#  '미래',
#  '민생',
#  '바로그',
#  '반칙',
#  '발전',
#  '번',
#  '베이징(北京)',
#  '보답',
#  '보수',
#  '부',
#  '북핵문제',
#  '분',
#  '분열',
#  '불가능',
#  '불구',
#  '불리',
#  '불행',
#  '브리핑',
#  '비롯',
#  '빈손',
#  '사는대통령',
#  '사람',
#  '사랑',
#  '사안은대통령',
#  '삼고초려(三顧草廬)해서',
#  '상식',
#  '선거',
#  '선대들',
#  '선택',
#  '성공',
#  '성원',
#  '세대',
#  '세상',
#  '세월',
#  '소명',
#  '소명감',
#  '소외',
#  '소통',
#  '손',
#  '솔선수범',
#  '솔직한',
#  '수',
#  '수시',
#  '순간',
#  '승자',
#  '시대',
#  '시민',
#  '시작',
#  '시장',
#  '신뢰',
#  '신명',
#  '심심',
#  '안보는막강한',
#  '안보위',
#  '안팎',
#  '앞',
#  '앞길',
#  '야당',
#  '약속',
#  '약속드',
#  '약속들',
#  '어깨',
#  '언론',
#  '여건',
#  '여러분',
#  '여론',
#  '여부',
#  '역사',
#  '역사가평가',
#  '열정',
#  '오늘',
#  '외면',
#  '우리',
#  '워싱턴',
#  '위대',
#  '위대한',
#  '위대함',
#  '위로',
#  '유능',
#  '이',
#  '이득',
#  '이번',
#  '이웃',
#  '이웃과',
#  '인사',
#  '인재',
#  '일',
#  '일관',
#  '일자리',
#  '자랑',
#  '자세',
#  '자주국방',
#  '잘못',
#  '잘못된',
#  '잘못한',
#  '장치',
#  '재벌',
#  '저',
#  '적재적소(適材適所)',
#  '전',
#  '전국',
#  '전기',
#  '전진',
#  '전화위복',
#  '젊은이들',
#  '정',
#  '정경유착',
#  '정규직',
#  '정부',
#  '정의',
#  '정착',
#  '정착시킴으로써한반',
#  '정치',
#  '정치적',
#  '제19대',
#  '제가',
#  '제왕적',
#  '조성',
#  '존경',
#  '종식',
#  '좌절',
#  '주요',
#  '준비',
#  '중국',
#  '지',
#  '지금',
#  '지역',
#  '지지',
#  '진보',
#  '진심',
#  '진정한',
#  '진지',
#  '질문',
#  '차별',
#  '참모',
#  '책',
#  '천명',
#  '첫걸음을내딛습니',
#  '청산',
#  '청와대',
#  '최선',
#  '추구',
#  '취',
#  '치열',
#  '친구',
#  '탄핵',
#  '토대',
#  '토론',
#  '통치하',
#  '통합',
#  '퇴근길',
#  '퇴임',
#  '특권',
#  '튼튼',
#  '패배',
#  '패자',
#  '평등',
#  '평범',
#  '평양',
#  '평화',
#  '필요',
#  '하나',
#  '한미동맹',
#  '한반',
#  '한편으로사드',
#  '해결',
#  '해소',
#  '행사',
#  '헌신',
#  '현직',
#  '협상',
#  '혼란',
#  '후보들',
#  '훗날',
#  '희생'}

# %%
from konlpy.tag import Komoran
komoran = Komoran()
komoran_r = komoran.nouns(speech)
print_result(komoran)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       2 komoran = Komoran()
#       3 komoran_r = komoran.nouns(speech)
# ----> 4 print_result(komoran)
#
# Cell In[24], line 2, in print_result(r)
#       1 def print_result(r: list):
# ----> 2     print(f'{len(r)}:{len(set(r))}')
#
# TypeError: object of type 'Komoran' has no len()

# %%
from konlpy.tag import Mecab
mecab = Mecab()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/code/edu/president-speech/.venv/lib/python3.8/site-packages/konlpy/tag/_mecab.py:77, in Mecab.__init__(self, dicpath)
#      76 try:
# ---> 77     self.tagger = Tagger('-d %s' % dicpath)
#      78     self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# NameError: name 'Tagger' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 from konlpy.tag import Mecab
# ----> 2 mecab = Mecab()
#
# File ~/code/edu/president-speech/.venv/lib/python3.8/site-packages/konlpy/tag/_mecab.py:82, in Mecab.__init__(self, dicpath)
#      80     raise Exception('The MeCab dictionary does not exist at "%s". Is the dictionary correctly installed?\nYou can also try entering the dictionary path when initializing the Mecab class: "Mecab(\'/some/dic/path\')"' % dicpath)
#      81 except NameError:
# ---> 82     raise Exception('Install MeCab in order to use it: http://konlpy.org/en/latest/install/')
#
# Exception: Install MeCab in order to use it: http://konlpy.org/en/latest/install/
